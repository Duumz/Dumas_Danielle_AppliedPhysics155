# %% [markdown]
# # **AP155 Lab Assignment**
# ## Module 2: Solution of Linear and Nonlinear Equations
#
# _Instructions_: Answer each problem as completely as you can. Discuss **all** your answers as clearly and concisely as possible.
#
# _Scoring Criteria_: 50% - *correctness of code*; 50% - *discussion of the code and results*. Maximum score is **100 points**.

# %% [markdown]
# ### Student Information
#
# _Full Name (Last Name, First Name)_: \
# _Student No._:\
# _Section_:

# %% [markdown]
# ### Submission Information
#
# _Date and Time Submitted (most recent upload)_:
#
# **HONOR PLEDGE** I affirm that I have upheld the highest principles of honesty and integrity in my academic work and that this lab assignment is my own work.
#
# **Sign here with your full name:**

# %% [markdown]
# ### Grading Information (c/o Lab Instructor)
#
# TOTAL SCORE: **XX**/100
#
# Score breakdown:
# * Problem 1 - XX/30
# * Problem 2 - XX/30
# * Problem 3 - XX/40

# %% [markdown]
# ### PROBLEM 1
#
# **Solve for eigenvalues and eigenvectors of a symmetric matrix**
#
# 1. Use numpy's $\tt linalg$ package to find the eigenvalues and eigenvectors of the ff. symmetrix matrix *(15 pts.)*:
#
# $ \begin{equation}
# {\bf A} =
# \begin{pmatrix}
# 8 & -2 & -20 \\
# -2 & -3 & -9 \\
# -20 & -9 & -3
# \end{pmatrix} \end{equation} $
#
# 2. Check your answer numerically; that is, check that $\bf AV = VD$, where the $N$ x $N$ matrix $\bf V$ has the eigenvectors as its columns and $\bf D$ is the diagonal matrix with the eigenvalues $\lambda_i$ as its diagonal entries. *(15 pts.)*

# %%
from numpy import array,matmul,diag
from numpy.linalg import eigh

print("Using numpy's linalg package")

A = array([[8,-2,-20],[-2,-3,-9],[-20,-9,-3]], float)
eigenvalues,eigenvectors = eigh(A)
print("Eigenvectors: " + str(eigenvectors))
print("Eigenvalues: " + str(eigenvalues))
#We know that for a N x N matrix, we will get N eigenvalues. Which is why we have a result in the form of an array with 3 elements, which are the 3 possible eigenvalues.
#The output gave us a result in the form of two arrays, wherein the first array consists of the respective eigenvalues (1x3 matrix) and the second array consist of the respective eigenvectors (3x3 matrix).

D = diag(eigenvalues)
V = eigenvectors

LHS = matmul(A,V)
RHS = matmul(V,D)

print("The left hand side AV gives us")
print(LHS)
print("Meanwhile, the right hand side VD gives us")
print(RHS)

print("We can see that the product matrices are equal to each other, therefore, we are certain that we have computed the correct eigenvalues and eigenfunctions.")
# Out:
# Using numpy's linalg package
# Eigenvectors: [[ 0.52496527  0.36793396 -0.76748685]
#  [ 0.40892672 -0.89987151 -0.15169114]
#  [ 0.74645187  0.2342133   0.62285932]]
# Eigenvalues: [-21.99606195   0.16021522  23.83584674]
# The left hand side AV gives us
# [[-11.54716868   0.05894862 -18.29369893]
#  [ -8.99477756  -0.14417311  -3.61568676]
#  [-16.4190016    0.03752454  14.8463793 ]]
# Meanwhile, the right hand side VD gives us
# [[-11.54716868   0.05894862 -18.29369893]
#  [ -8.99477756  -0.14417311  -3.61568676]
#  [-16.4190016    0.03752454  14.8463793 ]]
# We can see that the product matrices are equal to each other, therefore, we are certain that we have computed the correct eigenvalues and eigenfunctions.

# %% [markdown]
# ### PROBLEM 2
#
# **Solve a nonlinear equation using the relaxation method**
#
# Consider the equation $x=1- e^{-cx}$, where $c$ is a known parameter and $x$ is unknown. This equation arises in a variety of situations, including the physics of contact processes, mathematical models of epidemics, and the theory of random graphs.
#
# 1. Write a program to solve this equation for $x$ using the relaxation method for the case $c = 2$. Calculate your solution to an accuracy of at least $10^{-6}$. *(10 pts.)*
#
# 2. Modify your program to calculate the solution for values of $c$ from 0 to 3 in steps of 0.01. *(10 pts.)*
#
# 3. Make a plot of $x$ as a function of $c$. Describe the different regimes that you see. *(10 pts.)*

# %%
from math import exp
x1 = 1.0
c = 2.0
accuracy = 1e-6
error = 1.0
while error > accuracy: #we use this function and start with an error of 1.0 so we the loop constantly repeats until the error is small enough, which corresponds to a solution that is fairly accurate.
  x1,x2 = 1 - exp(-c*x1), x1
  error = abs((x1-x2)/(1-1/(c*exp(-c*x1)))) #(c*exp(-c*x1)) is the derivative of f(x), and it used in the formula that is found in the computational physics book
print("The solution is x = " + str(x1) + " with error: " + str(error))
# Out:
# The solution is x = 0.7968126311118457 with error: 5.010920207189714e-07

# %%
from math import exp
c = 0.01
while c <= 3.0: #since this code is just a modification to the first, I will just explain this part, we just need to make the loop go through different values of c from 0 to 3 in steps of 0.01
  accuracy = 1e-6
  error = 1
  x1 = 1.0
  print("For c = " + str(c))
  while error > accuracy:
    x1,x2 = 1 - exp(-c*x1), x1
    error = abs((x1-x2)/(1-1/(c*exp(-c*x1)))) #note that instead of 0, we used 0.1, because as we can see in error function, we will get an indeterminate of 1/0 if we let c=0, so we move on to the next step at c=0.01
  print(x1)
  c = c + 0.01 #this allows us to move to the next step for c
# Out:
# For c = 0.01
# 9.949666288644465e-07
# For c = 0.02
# 1.5837861067069525e-07
# For c = 0.03
# 7.976060235614923e-07
# For c = 0.04
# 1.0029708408243465e-07
# For c = 0.05
# 3.0442523768492435e-07
# For c = 0.060000000000000005
# 7.533307690987812e-07
# For c = 0.07
# 1.1333712901517856e-07
# For c = 0.08
# 2.510922193499354e-07
# For c = 0.09
# 5.060712903182107e-07
# For c = 0.09999999999999999
# 9.466140852287808e-07
# For c = 0.10999999999999999
# 1.8335386653411945e-07
# For c = 0.11999999999999998
# 3.350652155731382e-07
# For c = 0.12999999999999998
# 5.830870378753517e-07
# For c = 0.13999999999999999
# 9.732946213425464e-07
# For c = 0.15
# 2.3509530611143248e-07
# For c = 0.16
# 3.913687072198968e-07
# For c = 0.17
# 6.313573293059704e-07
# For c = 0.18000000000000002
# 9.905251162622974e-07
# For c = 0.19000000000000003
# 2.880129575943968e-07
# For c = 0.20000000000000004
# 4.5371695500673326e-07
# For c = 0.21000000000000005
# 6.987372471733977e-07
# ...

# %%
from math import exp
import matplotlib.pyplot as plt
import numpy as np

x_val = []
c = np.arange(0.0,3,0.01) #We just set c to go from c=0 to c=3 with a step=0.01
for i in np.arange(len(c)): #this loop allows to go through the different values of c
  #Constants
  x1 = 1
  error = 1
  accuracy = 1e-6
  while error > accuracy: #Same as the previous subitem, with the addition of i that allows us to loop from 0 to 3
    x2 = x1
    x1 = 1 - exp(-c[i]*x1)
    error = abs(x1-x2)
  x_val.append(x1)

#Plotting our values
fig,ax = plt.subplots()
ax.plot(c[1:],x_val[1:], color = 'red')
ax.set(title = "x as a function of c", xlabel = "values of c", ylabel = "values of x")
plt.show()

# %% [markdown]
# ### PROBLEM 3
#
# **Physics Application: Calculating the Lagrange point**
#
# _Refer to Exercise 6.16 of the Newman text._ The $L_1$ Lagrange point is the point between the Earth and the Moon at which a satellite will orbit the Earth in perfect synchrony with the Moon, staying always in between the two.
#
# Assuming circular orbits, and assuming that the Earth is much more massive than either the Moon or the satellite, the distance $r$ from the center of the Earth to the $L_1$ point satisfies
# $$ \begin{equation}
# \frac{GM}{r^2} - \frac{Gm}{(R-r)^2} = \omega^2 r,
# \end{equation} $$
# where $R$ is the distance from the Earth to the Moon, $M$ and $m$ are the Earth and Moon masses, $G$ is Newton's gravitational constant, and $\omega$ is the angular velocity of both the Moon and the satellite.

# %% [markdown]
# Use Newton's method to solve for the distance r from the Earth to the $L_1$ point. Compute a solution accurate to at least four significant figures.

# %%
import numpy as np

#Defining constants
G = 6.674e-11
M = 5.974e24
m = 7.348e22
R = 3.8440e8
w = 2.662e-6
r0 = 1
def f(r): #From the given equation
  return G*M/r**2 - G*m/(R-r)**2 - w**2*r
def df(r): #Differentiating f(r) with respect to r
  return -2*G*M/r**3 - 2*G*m/(R-r)**3 - w**2
def NewtonRaphson(r):
  h = f(r)/df(r)
  accuracy = 1e-4
  while abs(h) >= accuracy:
    h = f(r)/df(r)
    r = r-h #from Computational Physics Eq. 6.118
  print("r =", r)
NewtonRaphson(r0)
# Out:
# r = 326045071.66535544
